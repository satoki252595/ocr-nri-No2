# %%
import configparser

config = configparser.ConfigParser()
config.read('../config.ini')
key = config['setting']['ACCOUNT_KEY']
endpoint = config['setting']['END_POINT']

# %%
from img2table.ocr import TesseractOCR
from img2table.document import Image
from img2table.ocr import AzureOCR
import cv2
from PIL import Image as PILImage

PWD = '/Users/satoki252595/work/20240114_nriocr2'

PATH_IMAGE = PWD + '/static/image/'
PATH_TEXT = PWD + '/static/text/'

def getImageTable_Azuru(img_path):
    
    # Instantiation of OCR
    ocr = AzureOCR(endpoint=endpoint,subscription_key=key)

    # Instantiation of document, either an image or a PDF
    doc = Image(src = img_path)

    # Table extraction
    extracted_tables = doc.extract_tables(ocr=ocr,
                                        implicit_rows=True,
                                        borderless_tables=True,
                                        min_confidence=50)
    
    return extracted_tables

# %%
extracted_tables = getImageTable_Azuru(PATH_IMAGE + '4307.png')

# Display extracted tables
table_img = cv2.imread(PATH_IMAGE + '4307.png')

for table in extracted_tables:
    for row in table.content.values():
        for cell in row:
            cv2.rectangle(table_img, (cell.bbox.x1, cell.bbox.y1), (cell.bbox.x2, cell.bbox.y2), (255, 0, 0), 2)
            
PILImage.fromarray(table_img)
# Out:
# <PIL.Image.Image image mode=RGB size=1324x1030>

# %%
extracted_tables[0].df
# Out:
#                        0         1        2        3        4   \
# 0                    None   売 上 収 益  売 上 収 益  営 業 利 益  営 業 利 益
# 1                    None     百 万 円        %    百 万 円        %
# 2  2024 年 3 月 期 第 3 四 半 期  550, 019     6. 6  91, 239     8. 8
# 3  2023 年 3 月 期 第 3 四 半 期   516,059     15.2  83, 873      3.1
#
#                 5                6          7          8   \
# 0  税 引 前 四 半 期 利 益  税 引 前 四 半 期 利 益  四 半 期 利 益  四 半 期 利 益
# 1            百 万 円                %      百 万 円          %
# 2          89, 274              9.6     61,441       11.2
# 3           81,444             2. 0    55, 267        1.2
#
#                                     9                                    10  \
# 0  親 会 社 の\n所 有 者 に 帰 属 す る\n四 半 期 利 益  親 会 社 の\n所 有 者 に 帰 属 す る\n四 半 期 利 益
# 1                                百 万 円                                    %
# 2                               61,093                                 11.0
# 3                              55, 033                                  1.3
#
#                      11                    12
# 0  四 半 期 包 括 利 益\n合 計 額  四 半 期 包 括 利 益\n合 計 額
# 1                 百 万 円                     %
# 2               63, 645                  14.3
# 3               55, 682                  △2.8

# %%
extracted_tables[1].df
# Out:
#                         0                           1  \
# 0                    None  基 本 的 1 株 当 た り\n四 半 期 利 益
# 1                    None                         円 銭
# 2  2024 年 3 月 期 第 3 四 半 期                     104. 68
# 3  2023 年 3 月 期 第 3 四 半 期                       93.09
#
#                               2
# 0  希 薄 化 後 1 株 当 た り\n四 半 期 利 益
# 1                           円 銭
# 2                       104. 62
# 3                         93.00

# %%
extracted_tables[2].df
# Out:
#                         0         1         2                             3  \
# 0                    None   資 産 合 計   資 本 合 計  親 会 社 の 所 有 者 に\n帰 属 す る 持 分
# 1                    None     百 万 円     百 万 円                         百 万 円
# 2  2024 年 3 月 期 第 3 四 半 期   862,368  375, 185                       371,959
# 3            2023 年 3 月 期  838, 224  402, 406                       399,006
#
#                           4
# 0  親 会 社 所 有 者\n帰 属 持 分 比 率
# 1                         %
# 2                      43.1
# 3                      47.6

# %%
extracted_tables[3].df
# Out:
#                             0            1                    2            3  \
# 0                        None    年 間 配 当 金            年 間 配 当 金    年 間 配 当 金
# 1                        None  第 1 四 半 期 末          第 2 四 半 期 末  第 3 四 半 期 末
# 2  2023 年 3 月 期\n2024 年 3 月 期          円 銭  円 銭\n22. 00\n24. 00          円 銭
# 3  2023 年 3 月 期\n2024 年 3 月 期          円 銭  円 銭\n22. 00\n24. 00          円 銭
# 4        2024 年 3 月 期 ( 予 想 )         None                 None         None
#
#             4           5
# 0   年 間 配 当 金   年 間 配 当 金
# 1         期 末         合 計
# 2  円 銭\n23.00  円 銭\n45.00
# 3        None        None
# 4       29.00       53.00

# %% [markdown]
# 「.」と「,」の違いも区別できているため、Azuruなら文字認識完璧かも。普通の帳票なら利用できそう。
#
# df形式で格納が出来ているので、マスク処理は不要。事前に現新比較対象のセルの指定は必要。
# オブジェクトを貼り付けたり、事前に該当部分（X座標、Y座標を指定）することでマスク処理は可能。どっちが楽かは要検討。

# %%
##Azureセットアップ

import configparser

config = configparser.ConfigParser()
config.read('../config.ini')
key = config['setting']['ACCOUNT_KEY']
endpoint = config['setting']['END_POINT']

##OCR関数

from img2table.ocr import TesseractOCR
from img2table.document import Image
from img2table.ocr import AzureOCR
import cv2
from PIL import Image as PILImage

import os

##PWD = os.getcwd()
PWD = '/Users/satoki252595/work/20240114_nriocr2'

PATH_IMAGE = PWD + '/static/image/'

PATH_IMAGE = PWD + '/static/image/'
PATH_TEXT = PWD + '/static/text/'

def getImageTable_Azuru(img_path,lessFlag= False):
    
    # Instantiation of OCR
    ocr = AzureOCR(endpoint=endpoint,subscription_key=key)

    # Instantiation of document, either an image or a PDF
    doc = Image(src = img_path)

    
    # 見えない線を加味するかしないか。
    implicit_rows = False
    borderless_tables = False
    if lessFlag == True:
        implicit_rows = True
        borderless_tables = True
        

    # Table extraction
    extracted_tables = doc.extract_tables(ocr=ocr,
                                        implicit_rows=implicit_rows,
                                        borderless_tables=borderless_tables,
                                        min_confidence=50)
    
    return extracted_tables

def visualTable(extracted_tables,imageFileName,BA_Flag='mae'):

    if BA_Flag == 'mae':
        
        # Display extracted tables
        table_img = cv2.imread(PATH_IMAGE +'mae/'+imageFileName)

    if BA_Flag == 'ato':
        # Display extracted tables
        table_img = cv2.imread(PATH_IMAGE +'ato/'+imageFileName)
        

    for table in extracted_tables:
        for row in table.content.values():
            for cell in row:
                cv2.rectangle(table_img, (cell.bbox.x1, cell.bbox.y1), (cell.bbox.x2, cell.bbox.y2), (255, 0, 0), 2)
                
    return PILImage.fromarray(table_img)


    
t_mae = extracted_tables = getImageTable_Azuru(PATH_IMAGE + 'mae/'+ '4307.png',lessFlag = False)
t_ato = extracted_tables = getImageTable_Azuru(PATH_IMAGE + 'ato/'+ '4307.png',lessFlag = False)
vt_mae_image = visualTable(t_mae,'4307.png',BA_Flag='mae')
vt_ato_image = visualTable(t_ato,'4307.png',BA_Flag='ato')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 70
#      64                 cv2.rectangle(table_img, (cell.bbox.x1, cell.bbox.y1), (cell.bbox.x2, cell.bbox.y2), (255, 0, 0), 2)
#      66     return PILImage.fromarray(table_img)
# ---> 70 t_mae = extracted_tables = getImageTable_Azuru(PATH_IMAGE + 'mae/'+ '4307.png',lessFlag = False)
#      71 t_ato = extracted_tables = getImageTable_Azuru(PATH_IMAGE + 'ato/'+ '4307.png',lessFlag = False)
#      72 vt_mae_image = visualTable(t_mae,'4307.png',BA_Flag='mae')
#
# Cell In[40], line 36, in getImageTable_Azuru(img_path, lessFlag)
#      33 # Instantiation of document, either an image or a PDF
#      34 doc = Image(src = img_path)
# ---> 36 implicit_rows,borderless_tables = False
#      37 if lessFlag == True:
#      38     implicit_rows,borderless_tables = True
#
# TypeError: cannot unpack non-iterable bool object

# %%
vt_mae_image
# Out:
# <PIL.Image.Image image mode=RGB size=664x639>

# %%
vt_ato_image
# Out:
# <PIL.Image.Image image mode=RGB size=1006x679>

# %%
t_ato[3].df
# Out:
#               0         1         2                             3  \
# 0          None   資 産 合 計   資 本 合 計  親 会 社 の 所 有 者 に\n帰 属 す る 持 分
# 1          None     百 万 円     百 万 円                         百 万 円
# 2  2023 年 3 月 期  838, 224  402, 406                      399, 006
# 3  2022 年 3 月 期  789, 655  342, 486                      339, 360
#
#                           4                               5
# 0  親 会 社 所 有 者\n帰 属 持 分 比 率  1 株 当 た り 親 会 社\n所 有 者 帰 属 持 分
# 1                      None                             円 銭
# 2                      47.6                         674. 35
# 3                      43.0                         575. 59

# %%
for t in t_mae:
    print(t.df)
    print('---------------------')

for t in t_ato:
    print(t.df)
    print('---------------------')
# Out:
#              0         1        2         3      4          5          6   \
# 0          None   売 上 収 益  売 上 収 益     営 業 利  営 業 利  税 引 前 利 益  税 引 前 利 益
# 1          None     百 万 円       9%       百 円     96      百 万 円       None
# 2  2022 年 3 月 期  611. 634     11.1  106. 218   31.5   104. 671      47. 3
# 3  2021 年 3 月 期  550, 337      1.1   80, 748  △5. 7     71.075      416.9
#
#         7        8                                 9   \
# 0  当 期 利 益  当 期 利 益  親 会 社 の 所 有 者 に\n帰 属 す る 当 期 利 益
# 1    百 万 円       96                             百 万 円
# 2  71, 792     36.5                            71,445
# 3  52, 578    △11.0                            52,867
#
#                                  10                  11                  12
# 0  親 会 社 の 所 有 者 に\n帰 属 す る 当 期 利 益  当 期 包 括 利 益\n合 計 額  当 期 包 括 利 益\n合 計 額
# 1                                96               百 万 円                None
# 2                              35.1             83, 580                 2.1
# 3                              49.2             81, 882                 71.
# ---------------------
#               0                       1                           2  \
# 0          None  基 本 的 1 株 当 た り\n当 期 利  希 薄 化 後\n1 株 当 た り 当 期 利 益
